# %%
import warnings
warnings.filterwarnings('ignore')

import os
import re
import json
import webbrowser
import pandas as pd
import ipywidgets as widgets
from datetime import datetime
from ipywidgets import AppLayout, Button, Layout
from ipywidgets import Button, Layout, jslink, IntText, IntSlider
from IPython.display import display, Javascript, Markdown, clear_output, HTML
from ipywidgets import GridspecLayout
from markdown_it import MarkdownIt

# %%
# Declaring necessary variables and importing neccesary files for storing user answers and keep track of the visited pages
global stored_choices, path

stored_choices = {}
path = "../temp_storage.json"
back_path = "../backtracking.json"
dropdown_path = "../04_lu_tables/links.csv"
ques_nav_path = "../ques_nav_list.json"

# %%
# Creating button
def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto', border='1px solid black')) #width='max-content'

# %%
server_url = 'http://rc-decision-support-tool.ca/voila/render/'

# %%
notebook_name = "objective"

# %%
navigating_link = [(notebook_name, f"{server_url}{notebook_name+".ipynb"}")]

# %%
# navigating_link

# %%
# Read the dictionary back from the JSON file
with open(ques_nav_path, 'r') as f:
    ques_nav = json.load(f)

# %%
if not any(notebook_name in sublist for sublist in ques_nav["obj_list"]):
    ques_nav["obj_list"].extend(navigating_link)

# %%
with open (ques_nav_path, "w")as f:
    json.dump(ques_nav, f)

# %%
# Read the dictionary back from the JSON file
with open(ques_nav_path, 'r') as f:
    ques_nav = json.load(f)

# %%
#--------------EXPERIMENTING-------------------

# %%
# Create a placeholder for the clickable link
link_html = widgets.HTML(value="")

# Function to update the link beside the dropdown
def on_option_change(change):
    if change['new']:  # When a new option is selected
        with output:
            clear_output()
        label= change['new']
        link = change['new']
        if link:  # If the selected option has a valid link
            # Update the HTML widget to display a clickable link
            link_html.value = f'<a href="{link}" target="_blank">Open</a>'
        else:
            # Clear the link if 'None' or invalid option is selected
            link_html.value = ""

# %%
# ## Separate the whole progressbar + navigating dropdwon section into another notebook.---------------


drop_page_prog1 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["obj_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog1.observe(on_option_change, names='value')

drop_page_prog2 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["st_area_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog2.observe(on_option_change, names='value')

drop_page_prog3 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["dt_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog3.observe(on_option_change, names='value')

drop_page_prog4 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["ts_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog4.observe(on_option_change, names='value')

drop_page_prog5 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["ed_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog5.observe(on_option_change, names='value')

drop_page_prog6 = widgets.Dropdown(
    options = [(label, link) for label, link in ques_nav["da_list"]],
    layout = {'width' : 'max-content'}
)
drop_page_prog6.observe(on_option_change, names='value')


dropdown_prog_list = [drop_page_prog1, drop_page_prog2, drop_page_prog3, drop_page_prog4, drop_page_prog5, drop_page_prog6]

# Create a container for the dropdown and the link beside it
# container1 = widgets.HBox([drop_page_prog1, drop_page_prog2, drop_page_prog3, drop_page_prog4, drop_page_prog5, drop_page_prog6])  # use these pair as Vbox then concatenate all the pairs (6) with Hbox
# container2 = widgets.VBox([container1, link_html])  # use these pair as Vbox then concatenate all the pairs (6) with Hbox


# # Display the container
# display(container2)

# %%
# Creating image widgets for footer
image1 = widgets.Image(value=open("../03_icons/icon_progress-bar_num1.png", "rb").read(), format='png') #, layout=widgets.Layout(width='200px')
image2 = widgets.Image(value=open("../03_icons/icon_progress-bar_num2.png", "rb").read(), format='png')
image3 = widgets.Image(value=open("../03_icons/icon_progress-bar_num3.png", "rb").read(), format='png')
image4 = widgets.Image(value=open("../03_icons/icon_progress-bar_num4.png", "rb").read(), format='png')
image5 = widgets.Image(value=open("../03_icons/icon_progress-bar_num5.png", "rb").read(), format='png')
image6 = widgets.Image(value=open("../03_icons/icon_progress-bar_num6.png", "rb").read(), format='png')
image7 = widgets.Image(value=open("../03_icons/icon_progress-bar_num7.png", "rb").read(), format='png')
image8 = widgets.Image(value=open("../03_icons/icon_progress-bar_check.png", "rb").read(), format='png') # ALIF - ADDED IMAGE8


image_prog_list = [image1, image2, image3, image4, image5, image6, image7, image8]
# Creating text widgets for footer

text_space = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5"> </font>
    </div>
    """,
    layout=widgets.Layout(width='1px')
)

text1 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Objectives & resources</font>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)
text2 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;font-family: 'Arial', 'sans-serif';">
            <font size="2.5">Study area & Site selection constraints</font>
    </div>
    """,
    layout=widgets.Layout(width='11%') # Alif changed from 130px
)
text3 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Duration & Timing</font>
    </div>
    """,
    layout=widgets.Layout(width='10%') # Alif changed from 130px
)
text4 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Target Species</font>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)
text5 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Equipment & Deployment</font>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)
text6 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Data & Analysis</font>
    </div>
    """,
    layout=widgets.Layout(width='9%') # Alif changed from 130px
)
text7 = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <font size="2.5">Recommendations</font>
    </div>
    """,
    layout=widgets.Layout(width='11%') # Alif changed from 130px
)

text1_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Objectives & resources  </font></b>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)

text2_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Study area & Site selection constraints</font></b>
    </div>
    """,
    layout=widgets.Layout(width='11%') # Alif changed from 130px
)
text3_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Duration & Timing</font></b>
    </div>
    """,
    layout=widgets.Layout(width='10%') # Alif changed from 130px
)
text4_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Target Species</font></b>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)
text5_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Equipment & Deployment</font></b>
    </div>
    """,
    layout=widgets.Layout(width='8%') # Alif changed from 130px
)
text6_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Data & Analysis</font></b>
    </div>
    """,
    layout=widgets.Layout(width='9%') # Alif changed from 130px
)
text7_bold = widgets.HTML(
    value="""
    <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
            <b><font size="2">Recommendations</font></b>
    </div>
    """,
    layout=widgets.Layout(width='11%') # Alif changed from 130px
)


text_prog_list = [text_space, text1, text2, text3, text4, text5, text6, text7,
                 text1_bold, text2_bold, text3_bold, text4_bold, text5_bold, text6_bold, text7_bold]

# Creating footer container with image and text widgets
## Footer by progress bar "level"

### progress_bar_text_1=="Objectives & Resources"
footer_in_prog1 = widgets.HBox([text_space, text_space, image1, text1_bold, image2, text2, image3, text3, image4, text4, image5, text5, image6, text6, image7, text7, text_space], 
                    layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

### progress_bar_text_2=="Study area & Site selection constraints"
footer_in_prog2 = widgets.HBox([image8, text1, image2, text2_bold, image3, text3, image4, text4, image5, text5, image6, text6, image7, text7], 
                     layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

### progress_bar_text_3=="Duration & Timing"
footer_in_prog3 = widgets.HBox([image8, text1, image8, text2, image3, text3_bold, image4, text4, image5, text5, image6, text6, image7, text7], 
                    layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

### progress_bar_text_4=="Target species"
footer_in_prog4 = widgets.HBox([image8, text1, image8, text2, image8, text3, image4, text4_bold, image5, text5, image6, text6, image7, text7],  
                     layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

### progress_bar_text_5=="Equipment & Deployment"
footer_in_prog5 = widgets.HBox([image8, text1, image8, text2, image8, text3, image8, text4, image5, text5_bold, image6, text6, image7, text7], 
                    layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

### progress_bar_text_6=="Data & Analysis"
footer_in_prog6 = widgets.HBox([image8, text1, image8, text2, image8, text3, image8, text4, image8, text5, image6, text6_bold, image7, text7], 
                   layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))


footer_in = footer_in_prog1

# Adding custon css class to the container
footer_in.add_class("custom-vbox")

# Creating another footer container with the previous container for implementing other css properties
footer = widgets.HBox([footer_in], 
                    layout=widgets.Layout(
        width='95%',  # Set the width to 50% of the container or viewport
        height='auto',  # Set a fixed height
#         border='solid 2px grey',
        padding='1px',
        margin='auto',  # Center the VBox horizontally
        align_items='center',  # Center the items inside the VBox
        justify_content='center'  # Center the items vertically inside the VBox
    ))

# %%
first_block = widgets.VBox([widgets.HBox([image1, text1_bold]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block = widgets.VBox([widgets.HBox([image2, text2]), drop_page_prog2])
third_block = widgets.VBox([widgets.HBox([image3, text3]), drop_page_prog3])
fourth_block = widgets.VBox([widgets.HBox([image4, text4]), drop_page_prog4])
fifth_block = widgets.VBox([widgets.HBox([image5, text5]), drop_page_prog5])
sixth_block = widgets.VBox([widgets.HBox([image6, text6]), drop_page_prog6])
seventh_block = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_1=="Objectives & Resources"
footer_in_prog1 = widgets.HBox([text_space, text_space, first_block, second_block, third_block, fourth_block, fifth_block, sixth_block, seventh_block, text_space], 
                    layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))


first_block2 = widgets.VBox([widgets.HBox([image8, text1]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block2 = widgets.VBox([widgets.HBox([image2, text2_bold]), drop_page_prog2])
third_block2 = widgets.VBox([widgets.HBox([image3, text3]), drop_page_prog3])
fourth_block2 = widgets.VBox([widgets.HBox([image4, text4]), drop_page_prog4])
fifth_block2 = widgets.VBox([widgets.HBox([image5, text5]), drop_page_prog5])
sixth_block2 = widgets.VBox([widgets.HBox([image6, text6]), drop_page_prog6])
seventh_block2 = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_2=="Study area & Site selection constraints"
footer_in_prog2 = widgets.HBox([first_block2, second_block2, third_block2, fourth_block2, fifth_block2, sixth_block2, seventh_block2], 
                     layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))


first_block3 = widgets.VBox([widgets.HBox([image8, text1]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block3 = widgets.VBox([widgets.HBox([image8, text2]), drop_page_prog2])
third_block3 = widgets.VBox([widgets.HBox([image3, text3_bold]), drop_page_prog3])
fourth_block3 = widgets.VBox([widgets.HBox([image4, text4]), drop_page_prog4])
fifth_block3 = widgets.VBox([widgets.HBox([image5, text5]), drop_page_prog5])
sixth_block3 = widgets.VBox([widgets.HBox([image6, text6]), drop_page_prog6])
seventh_block3 = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_3=="Duration & Timing"
footer_in_prog3 = widgets.HBox([first_block3, second_block3, third_block3, fourth_block3, fifth_block3, sixth_block3, seventh_block3], 
                    layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))


first_block4 = widgets.VBox([widgets.HBox([image8, text1]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block4 = widgets.VBox([widgets.HBox([image8, text2]), drop_page_prog2])
third_block4 = widgets.VBox([widgets.HBox([image8, text3]), drop_page_prog3])
fourth_block4 = widgets.VBox([widgets.HBox([image4, text4_bold]), drop_page_prog4])
fifth_block4 = widgets.VBox([widgets.HBox([image5, text5]), drop_page_prog5])
sixth_block4 = widgets.VBox([widgets.HBox([image6, text6]), drop_page_prog6])
seventh_block4 = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_4=="Target species"
footer_in_prog4 = widgets.HBox([first_block4, second_block4, third_block4, fourth_block4, fifth_block4, sixth_block4, seventh_block4],  
                     layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))


first_block5 = widgets.VBox([widgets.HBox([image8, text1]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block5 = widgets.VBox([widgets.HBox([image8, text2]), drop_page_prog2])
third_block5 = widgets.VBox([widgets.HBox([image8, text3]), drop_page_prog3])
fourth_block5 = widgets.VBox([widgets.HBox([image8, text4]), drop_page_prog4])
fifth_block5 = widgets.VBox([widgets.HBox([image5, text5_bold]), drop_page_prog5])
sixth_block5 = widgets.VBox([widgets.HBox([image6, text6]), drop_page_prog6])
seventh_block5 = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_5=="Equipment & Deployment"
footer_in_prog5 = widgets.HBox([first_block5, second_block5, third_block5, fourth_block5, fifth_block5, sixth_block5, seventh_block5], 
                    layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))


first_block6 = widgets.VBox([widgets.HBox([image8, text1]), drop_page_prog1]) # layout= {'width' : 'max-content'}
second_block6 = widgets.VBox([widgets.HBox([image8, text2]), drop_page_prog2])
third_block6 = widgets.VBox([widgets.HBox([image8, text3]), drop_page_prog3])
fourth_block6 = widgets.VBox([widgets.HBox([image8, text4]), drop_page_prog4])
fifth_block6 = widgets.VBox([widgets.HBox([image8, text5]), drop_page_prog5])
sixth_block6 = widgets.VBox([widgets.HBox([image6, text6_bold]), drop_page_prog6])
seventh_block6 = widgets.VBox([widgets.HBox([image7, text7]), drop_page_prog6])

### progress_bar_text_6=="Data & Analysis"
footer_in_prog6 = widgets.HBox([first_block6, second_block6, third_block6, fourth_block6, fifth_block6, sixth_block6, seventh_block6], 
                   layout=widgets.Layout(width='100%', height='100px', border='solid grey 1px'))
