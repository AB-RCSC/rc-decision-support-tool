# %%
# ALIF CAN IGNORE; JUST MESSING AROUND WITH FOOTER TO TRY TO KEEP FIXED WIDTH FOR TEXT.
import webbrowser
import ipywidgets as widgets
from ipywidgets import AppLayout, Button, Layout
from ipywidgets import Button, Layout, jslink, IntText, IntSlider
from IPython.display import display, Javascript, Markdown, clear_output, HTML
from ipywidgets import GridspecLayout

# # Creating image widgets for footer
# prog1_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num1.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog2_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num2.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog3_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num3.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog4_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num4.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog5_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num5.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog6_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num6.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog7_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_num7.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# check_icon = widgets.Image(value=open("./03_images/03_icons/icon_progress-bar_check.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))

# prog1_text = widgets.Image(value=open("./03_images/03_icons/prog1_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog2_text = widgets.Image(value=open("./03_images/03_icons/prog2_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='120px'))
# prog3_text = widgets.Image(value=open("./03_images/03_icons/prog3_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog4_text = widgets.Image(value=open("./03_images/03_icons/prog4_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog5_text = widgets.Image(value=open("./03_images/03_icons/prog5_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog6_text = widgets.Image(value=open("./03_images/03_icons/prog6_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog7_text = widgets.Image(value=open("./03_images/03_icons/prog7_normal.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))

# prog1_bold = widgets.Image(value=open("./03_images/03_icons/prog1_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog2_bold = widgets.Image(value=open("./03_images/03_icons/prog2_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='120px'))
# prog3_bold = widgets.Image(value=open("./03_images/03_icons/prog3_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog4_bold = widgets.Image(value=open("./03_images/03_icons/prog4_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog5_bold = widgets.Image(value=open("./03_images/03_icons/prog5_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog6_bold = widgets.Image(value=open("./03_images/03_icons/prog6_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))
# prog7_bold = widgets.Image(value=open("./03_images/03_icons/prog7_bold.png", "rb").read(), format='png', layout=widgets.Layout(height='62px'))

# # ### progress_bar_text_2=="Study area & Site selection constraints"
# # footer_in_prog2 = widgets.HBox([check_icon, prog1_text, prog2_icon, prog2_bold, prog3_icon, prog3_text, prog4_icon, prog4_text, prog5_icon, prog5_text, prog6_icon, prog6_text, prog7_icon, prog7_text], 
# #                      layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# # ### progress_bar_text_3=="Duration & Timing"
# # footer_in_prog3 = widgets.HBox([check_icon, prog1_text, check_icon, prog2_text, prog3_icon, prog3_bold, prog4_icon, prog4_text, prog5_icon, prog5_text, prog6_icon, prog6_text, prog7_icon, prog7_text], 
# #                     layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# # ### progress_bar_text_4=="Target species"
# # footer_in_prog4 = widgets.HBox([check_icon, prog1_text, check_icon, prog2_text, check_icon, prog3_text, prog4_icon, prog4_bold, prog5_icon, prog5_text, prog6_icon, prog6_text, prog7_icon, prog7_text],  
# #                      layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# # ### progress_bar_text_5=="Equipment & Deployment"
# # footer_in_prog5 = widgets.HBox([check_icon, prog1_text, check_icon, prog2_text, check_icon, prog3_text, check_icon, prog4_text, prog5_icon, prog5_bold, prog6_icon, prog6_text, prog7_icon, prog7_text], 
# #                     layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# # ### progress_bar_text_6=="Data & Analysis"
# # footer_in_prog6 = widgets.HBox([check_icon, prog1_text, check_icon, prog2_text, check_icon, prog3_text, check_icon, prog4_text, check_icon, prog5_text, prog6_icon, prog6_bold, prog7_icon, prog7_text], 
# #                    layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# # ### progress_bar_text_7=="Recommendations"
# # #footer_in_prog7 = widgets.HBox([check_icon, prog1_text, check_icon, prog2_text, check_icon, prog3_text, check_icon, prog4_text, check_icon, prog5_text, check_icon, prog6_text, prog7_icon, prog7_bold],  
# # #                     layout=widgets.Layout(width='100%', height='62px', border='solid grey 1px'))

# text_space = widgets.HTML(
#     value="""
#     <div style="display: flex; line-height: 1.2; align-items: center; white-space: normal; justify-content: flex-start; height: 100%; width: 100%;">
#             <font size="2.5"> </font>
#     </div>
#     """,
#     layout=widgets.Layout(width='1px')
# )

# footer_in = widgets.HBox([prog1_icon, prog1_bold, prog2_icon, prog2_bold, prog3_icon, prog3_text, prog4_icon, prog4_text, prog5_icon, prog5_text, prog6_icon, prog6_text, prog7_icon, prog7_text], 
#                     layout=widgets.Layout(width='100%', height='80px', border='solid grey 1px'))
# footer_in.add_class("custom-vbox")

# # Creating another footer container with the previous container for implementing other css properties
# footer = widgets.HBox([footer_in], 
#                     layout=widgets.Layout(
#         width='100%',  # Set the width to 50% of the container or viewport
#         height='100%',  # Set a fixed height
# #         border='solid 2px grey',
#         padding='1px',
#         margin='auto',  # Center the VBox horizontally
#         align_items='center',  # Center the items inside the VBox
#         justify_content='center'  # Center the items vertically inside the VBox
#     ))

# %%
# footer

# %%
## ALL QUESTIONS

drop_page_prog1 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'user_entry', 
                'objective', 
                'num_cams', 
            ],
            layout={'width': 'max-content'}
        )
    ]
)

drop_page_prog2 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'study_area_mult',
                'cam_dens_gradient',
                'cam_strat_covar',
                'cam_high_dens',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

drop_page_prog3 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'surv_dur_min_max',
                'survey_dur_mth',
                'sp_asymptote',
                'study_season_num',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

drop_page_prog4 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'obj_targ_sp',
                'sp_info',
                'sp_type',
                'sp_dens_low',
                'sp_occ_restr',
                'sp_hr_size',
                'sp_size',
                'sp_rarity',
                'sp_detprob_cat',
                'sp_behav',
                'sp_behav_season',
                'marking_code',
                'marking_allsub',
                '3ormore_cat_ids',
                'auxillary_info',
                'aux_count_possible',
                'focalarea_calc',
                'sp_common_pop_lg',
                'sp_size_multi',
                'sp_behav_mult',
                'sp_rarity_multi',
                'sp_detprob_cat_multi',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

drop_page_prog5 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'cam_protocol_ht_angle_dir',
                'bait_lure',
                'cam_targ_feature',
                'cam_makemod_same',
                'cam_settings_mult',
                'cam_protocol_ht_angle_dir',
                'bait_lure',
                'cam_targ_feature',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

drop_page_prog6 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'cam_independent',
                'multisamp_per_loc',
                'modmixed',
                'num_det',
                'num_det_individ',
                'num_recap',
                'overdispersion',
                'zeroinflation',
                'zi_overdispersed',
                'zi_re_overdispersed',
                'zi_process',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

# NOTE we don't necessarily want "max content" here, they should align with the current progress bar items. where "drop_page_prog1" is under both the "1" image + "Objectives & Resources"

# %%
## DEMO ONLY

demo_drop_page_prog1 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '', 
                'objective', 
                'num_cams', 
            ],
            layout={'width': 'max-content'}
        )
    ]
)

demo_drop_page_prog2 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'cam_strat_covar',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

demo_drop_page_prog3 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'surv_dur_min_max',
                'sp_asymptote',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

demo_drop_page_prog4 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'obj_targ_sp',
                'sp_info',
                'sp_type',
                'sp_hr_size',
                'sp_size',
                'sp_rarity',
                'sp_detprob_cat',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

demo_drop_page_prog5 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '                                ',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

demo_drop_page_prog6 = widgets.Box(
    [
        widgets.Label(value=''), 
        widgets.Dropdown(
            options=[
                '',
                'cam_independent',
            ],
            layout={'width': 'max-content'}
        )
    ]
)

# NOTE we don't necessarily want "max content" here, they should align with the current progress bar items. where "drop_page_prog1" is under both the "1" image + "Objectives & Resources"
# CAN ALSO JUST MAKE default empty from '' --> '                                ' to change width (see prog 5 here)

demo_dropdown_page = widgets.HBox([demo_drop_page_prog1, demo_drop_page_prog2, demo_drop_page_prog3, demo_drop_page_prog4, demo_drop_page_prog5, demo_drop_page_prog6], 
                   layout=widgets.Layout(width='100%', border='solid grey 1px', justify_content='space-between'))
demo_dropdown_page

# %%
# import ipywidgets as widgets
# from IPython.display import display, HTML, clear_output

# # Define the options with labels and corresponding links
# dropdown_options = [
#     ('Select an option', ''),
#     ('Objective', 'https://example.com/objective'),
#     ('Number of Cameras', 'https://example.com/num_cams')
# ]

# # Create a Dropdown widget
# dropdown = widgets.Dropdown(
#     options=dropdown_options,  # Using (label, link) tuples
#     layout={'width': 'max-content'}
# )

# # Function to display the link when an option is selected
# def on_dropdown_change(change):
#     if change['type'] == 'change' and change['name'] == 'value':
#         selected_link = change['new']
#         clear_output()  # Clear the previous output
#         display(dropdown)  # Re-display the dropdown
#         if selected_link:
#             display(HTML(f'<a href="{selected_link}" target="_blank">Go to selected option</a>'))

# # Attach the function to the Dropdown
# dropdown.observe(on_dropdown_change)

# # Display the dropdown widget
# display(dropdown)

# %%
# # Create a link widget (initially hidden)
# # link = widgets.HTML(value='', layout={'display': 'none'})

# # Function to open the link automatically when an option is selected
# def on_dropdown_change(change):
#     if change['type'] == 'change' and change['name'] == 'value':
#         selected_link = change['new']
#         if selected_link:
#             print("eeeee")
#             link = f"window.open('{selected_link}', '_blank');"
#             display(Javascript(link))  # Trigger the link using HTML

# %%
# ###----------------- WORKING SAMPLE------------------###


# import ipywidgets as widgets
# import webbrowser
# from IPython.display import display

# # Dropdown options with labels and associated links
# dropdown = widgets.Dropdown(
#     options=[
#         ('Select an option', None),
#         ('Google', 'https://www.google.com'),
#         ('GitHub', 'https://github.com'),
#         ('StackOverflow', 'https://stackoverflow.com')
#     ],
#     description='Links:',
# )

# # Function to open the selected link in the browser
# def on_option_change(change):
#     if change['new']:
#         link = change['new']
#         if link:
#             webbrowser.open(link)

# # Attach the function to the dropdown selection change
# dropdown.observe(on_option_change, names='value')

# # Create a container for the dropdown
# container = widgets.VBox([dropdown])

# # Display the container
# display(container)

# %%
# # WORKING DEMO DROPDOWN WITH ALL THE NOTEBOOKS-----------------

# import os
# import ipywidgets as widgets
# import webbrowser
# from IPython.display import display

# # Your server URL (replace with your actual server domain and port)
# server_url = 'http://rc-decision-support-tool.ca/voila/render/'

# # List all .ipynb files in the current directory
# notebooks = [f for f in os.listdir() if f.endswith('.ipynb')]


# # Create dropdown options from the notebook names
# dropdown_options = [('Select a notebook', None)] + [(nb, f"{server_url}{nb}") for nb in notebooks]
# # print(dropdown_options)

# # Create a dropdown widget dynamically
# dropdown = widgets.Dropdown(
#     options=dropdown_options,
#     description='Notebooks:',
# )

# # Function to open the selected notebook link
# def on_option_change(change):
#     if change['new']:
#         link = change['new']
#         if link:
#             webbrowser.open(link)

# # Attach the function to the dropdown selection change
# dropdown.observe(on_option_change, names='value')

# # Create a container for the dropdown
# container = widgets.VBox([dropdown])

# # Display the container
# display(container)

# %%
# notebooks

# %%
import webbrowser

# Function to open the link automatically when an option is selected
def on_dropdown_change(change):
    if change['new']:
        link = change['new']
        if link:
            webbrowser.open(link)

# %%
## DEMO ONLY

demo_drop_page_prog1 =widgets.Dropdown(
            options=[
                ('', ''),
    ('objective', 'objective.ipynb'),
    ('num_cams', 'https://example.com/num_cams') 
            ],
            layout={'width': 'max-content'}
        )

demo_drop_page_prog1.observe(on_dropdown_change, names='value')



demo_drop_page_prog2 = widgets.Dropdown(
            options=[
                ('', ''),
    ('cam_strat_covar', 'https://example.com/objective')
            ],
            layout={'width': 'max-content'}
        )
        
demo_drop_page_prog2.observe(on_dropdown_change, names='value')



demo_drop_page_prog3 = widgets.Dropdown(
            options=[
                ('', ''),
    ('surv_dur_min_max', 'https://example.com/objective'),
    ('sp_asymptote', 'https://example.com/num_cams')
            ],
            layout={'width': 'max-content'}
        )
demo_drop_page_prog3.observe(on_dropdown_change, names='value')


demo_drop_page_prog4 = widgets.Dropdown(
            options=[
                ('', ''),
    ('obj_targ_sp', 'https://example.com/objective'),
    ('sp_info', 'https://example.com/num_cams'),
    ('sp_type', 'https://example.com/objective'),
    ('sp_hr_size', 'https://example.com/num_cams'),
    ('sp_size', 'https://example.com/objective'),
    ('sp_rarity', 'https://example.com/num_cams'),
    ('sp_detprob_cat', 'https://example.com/objective')
            ],
            layout={'width': 'max-content'}
        )
demo_drop_page_prog4.observe(on_dropdown_change, names='value')


demo_drop_page_prog5 = widgets.Dropdown(
            options=[
                ('', ''),
            ],
            layout={'width': 'max-content'}
        )
demo_drop_page_prog5.observe(on_dropdown_change, names='value')


demo_drop_page_prog6 = widgets.Dropdown(
            options=[
                ('', ''),
    ('cam_independent', 'https://example.com/objective')
            ],
            layout={'width': 'max-content'}
        )
demo_drop_page_prog6.observe(on_dropdown_change, names='value')


# NOTE we don't necessarily want "max content" here, they should align with the current progress bar items. where "drop_page_prog1" is under both the "1" image + "Objectives & Resources"
# CAN ALSO JUST MAKE default empty from '' --> '                                ' to change width (see prog 5 here)

demo_dropdown_page = widgets.HBox([demo_drop_page_prog1, demo_drop_page_prog2, demo_drop_page_prog3, demo_drop_page_prog4, demo_drop_page_prog5, demo_drop_page_prog6], 
                   layout=widgets.Layout(width='95%', height='auto', border='solid grey 1px', justify_content='space-between'))
demo_dropdown_page

# %%
# import ipywidgets as widgets
# from IPython.display import display

# # Define the options with labels and corresponding links
# dropdown_options = [
#     ('Select an option', ''),
#     ('Objective', 'https://example.com/objective'),
#     ('Number of Cameras', 'https://example.com/num_cams')
# ]

# # Create a Dropdown widget
# dropdown = widgets.Dropdown(
#     options=dropdown_options,
#     description='Select:',
#     layout={'width': 'max-content'}
# )

# # Create a Button widget
# button = widgets.Button(
#     description='Open Link',
#     layout={'width': 'max-content'},
#     disabled=True  # Disabled by default until an option is selected
# )

# # Function to handle dropdown changes and enable the button
# def on_dropdown_change(change):
#     if change['new']:
# #         button.description = f"Open {change['new']}"
#         button.url = change['new']
#         button.disabled = False  # Enable the button when a valid option is selected
#     else:
#         button.disabled = True

# # Attach the function to the dropdown change event
# dropdown.observe(on_dropdown_change, names='value')

# # Function to handle button click and open the link
# def on_button_click(b):
#     if hasattr(b, 'url') and b.url:
#         display(Javascript(f'window.open("{b.url}", "_blank");'))

# # Attach the button click event
# button.on_click(on_button_click)

# # Display the dropdown and button
# display(dropdown, button)

# %%
# import ipywidgets as widgets
# from IPython.display import display

# # Define the options with labels and corresponding links
# dropdown_options = [
#     ('Select an option', ''),
#     ('Objective', 'https://example.com/objective'),
#     ('Number of Cameras', 'https://example.com/num_cams')
# ]

# # Create a Dropdown widget
# dropdown = widgets.Dropdown(
#     options=dropdown_options,
#     description='Select:',
#     layout={'width': 'max-content'}
# )

# # Create an output area for link display
# output = widgets.Output()

# # Function to handle dropdown changes
# def on_dropdown_change(change):
#     with output:
#         output.clear_output()  # Clear previous output
#         selected_link = change['new']
#         if selected_link:
#             # Display the link as a clickable HTML element
#             display(widgets.HTML(f'<a href="{selected_link}" target="_blank">Open link</a>'))

# # Attach the function to the dropdown change event
# dropdown.observe(on_dropdown_change, names='value')

# # Display the dropdown and output area
# display(dropdown, output)

# %%
# # Simple tooltip with html button

# from IPython.display import display, HTML, Javascript

# # Load Bootstrap CSS and JS
# bootstrap_css = """
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-GLhlTQ8iRABdZLl6O3oVMWSktQOp6b7In1Zl3/Jr59b6EGGoI1NsIBr7AZN0pKeH" crossorigin="anonymous">
# """
# bootstrap_js = """
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/js/bootstrap.bundle.min.js" integrity="sha384-ho+j7jyWK8fNQe+A12W7ZrF+QJncF3smbzt0fC2jzA5GsIr2RzId2WezJlZfl6Q" crossorigin="anonymous"></script>
# """

# # Button with tooltip
# button_html = """
# <button type="button" class="btn btn-secondary" data-bs-toggle="tooltip" data-bs-placement="top" title="Tooltip on top">
#   Tooltip Button
# </button>

# <script>
# var tooltipTriggerList = [].slice.call(document.querySelectorAll('[data-bs-toggle="tooltip"]'));
# var tooltipList = tooltipTriggerList.map(function (tooltipTriggerEl) {
#   return new bootstrap.Tooltip(tooltipTriggerEl);
# });
# </script>
# """

# # Display the content
# display(HTML(bootstrap_css + bootstrap_js + button_html))

# %%
# # Load Bootstrap CSS and JS
# bootstrap_css = """
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-GLhlTQ8iRABdZLl6O3oVMWSktQOp6b7In1Zl3/Jr59b6EGGoI1NsIBr7AZN0pKeH" crossorigin="anonymous">
# """
# bootstrap_js = """
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/js/bootstrap.bundle.min.js" integrity="sha384-ho+j7jyWK8fNQe+A12W7ZrF+QJncF3smbzt0fC2jzA5GsIr2RzId2WezJlZfl6Q" crossorigin="anonymous"></script>
# """

# # Display Bootstrap CSS and JS
# display(HTML(bootstrap_css + bootstrap_js))

# %%
# # Correct way to insert the dynamic tooltip text with Python f-string
# tooltip_js_template = """
# <script>
#   setTimeout(function() {{
#       var btn = document.querySelector('.widget-button');
#       btn.setAttribute('data-bs-toggle', 'tooltip');
#       btn.setAttribute('data-bs-placement', 'top');
#       btn.setAttribute('title', '{tooltip_text}');
      
#       // Initialize the Bootstrap tooltip
#       var tooltipTriggerList = [].slice.call(document.querySelectorAll('[data-bs-toggle="tooltip"]'));
#       var tooltipList = tooltipTriggerList.map(function (tooltipTriggerEl) {{
#           return new bootstrap.Tooltip(tooltipTriggerEl);
#       }});
#   }}, 1000);
# </script>
# """

# %%
# import ipywidgets as widgets
# from IPython.display import display, HTML

# # Define the dynamic tooltip text in a Python variable
# # tooltip_text = "Dynamic Tooltip Text"

# # Create a button widget
# button = widgets.Button(description="Hover for Tooltip")
# button.style.button_color = '#6c757d'  # Bootstrap secondary button color

# # Create a button widget
# button2 = widgets.Button(description="Hover for Tooltip2")
# button2.style.button_color = '#6c757d'  # Bootstrap secondary button color
# # Display the button widget


# tooltip_js = tooltip_js_template.format(tooltip_text="new tooltip text")
# tooltip_js2 = tooltip_js_template.format(tooltip_text="new tooltip text2")

# display(button, HTML(tooltip_js))
# display(button2, HTML(tooltip_js2))

# # Inject JavaScript to activate the tooltip with dynamic title
# # display(HTML(tooltip_js))

# %%
# # # Tooltip texts for each button with button widget attributes-----------------------------------------------------

# import ipywidgets as widgets
# from IPython.display import display, HTML

# # Create a GridSpecLayout for 4 buttons (2 rows, 2 columns)
# grid = widgets.GridspecLayout(2, 2, height='200px', width='400px')

# # Create the buttons with different descriptions
# button1 = widgets.Button(description="Button 1")
# button2 = widgets.Button(description="Button 2")
# button3 = widgets.Button(description="Button 3")
# button4 = widgets.Button(description="Button 4")


# button1.tooltip = "Tooltip for Button 1"
# button2.tooltip = "Tooltip for Button 2"
# button3.tooltip = "Tooltip for Button 3"
# button4.tooltip = "Tooltip for Button 4"

# # Add buttons to the grid
# grid[0, 0] = button1
# grid[0, 1] = button2
# grid[1, 0] = button3
# grid[1, 1] = button4

# # Display the grid
# display(grid)



# # Tooltip texts for each button with Bootstrap-----------------------------------------------------

# # Load Bootstrap CSS and JS for tooltip functionality
# bootstrap_css = """
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-GLhlTQ8iRABdZLl6O3oVMWSktQOp6b7In1Zl3/Jr59b6EGGoI1NsIBr7AZN0pKeH" crossorigin="anonymous">
# """
# bootstrap_js = """
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/js/bootstrap.bundle.min.js" integrity="sha384-ho+j7jyWK8fNQe+A12W7ZrF+QJncF3smbzt0fC2jzA5GsIr2RzId2WezJlZfl6Q" crossorigin="anonymous"></script>
# """

# # Display Bootstrap CSS and JS
# display(HTML(bootstrap_css + bootstrap_js))



# tooltips = {
#     "Button 1": "Tooltip for Button 1",
#     "Button 2": "Tooltip for Button 2",
#     "Button 3": "Tooltip for Button 3",
#     "Button 4": "Tooltip for Button 4",
# }

# # JavaScript to add tooltips to each button dynamically
# tooltip_jss = f"""
# <script>
#   setTimeout(function() {{
#       // Button 1
#       var btn1 = document.querySelectorAll('.widget-button')[0];
#       btn1.setAttribute('data-bs-toggle', 'tooltip');
#       btn1.setAttribute('data-bs-placement', 'top');
#       btn1.setAttribute('title', '{tooltips["Button 1"]}');
      
#       // Button 2
#       var btn2 = document.querySelectorAll('.widget-button')[1];
#       btn2.setAttribute('data-bs-toggle', 'tooltip');
#       btn2.setAttribute('data-bs-placement', 'top');
#       btn2.setAttribute('title', '{tooltips["Button 2"]}');
      
#       // Button 3
#       var btn3 = document.querySelectorAll('.widget-button')[2];
#       btn3.setAttribute('data-bs-toggle', 'tooltip');
#       btn3.setAttribute('data-bs-placement', 'top');
#       btn3.setAttribute('title', '{tooltips["Button 3"]}');
      
#       // Button 4
#       var btn4 = document.querySelectorAll('.widget-button')[3];
#       btn4.setAttribute('data-bs-toggle', 'tooltip');
#       btn4.setAttribute('data-bs-placement', 'top');
#       btn4.setAttribute('title', '{tooltips["Button 4"]}');
      
#       // Initialize all tooltips
#       var tooltipTriggerList = [].slice.call(document.querySelectorAll('[data-bs-toggle="tooltip"]'));
#       var tooltipList = tooltipTriggerList.map(function (tooltipTriggerEl) {{
#           return new bootstrap.Tooltip(tooltipTriggerEl);
#       }});
#   }}, 1000);
# </script>
# """

# Inject JavaScript to activate the tooltips
# display(HTML(tooltip_jss))

# %%
# import ipywidgets as widgets
# from IPython.display import display

# # Add an icon to the button using HTML
# button = widgets.Button(
#     description='My Button',
#     layout=widgets.Layout(width='150px', height='50px'),
#     style={'button_color': 'lightblue'}
# )

# # Use HTML to insert an icon in the button's description
# button_with_icon = widgets.HTML(
#     value='<button style="position:relative; width:100%; height:100%; background-color:lightblue; border:none;">'
#           'My Button <i class="fa fa-info-circle" style="position:absolute; top:5px; right:5px;"></i>'
#           '</button>'
# )

# # Display the button with the icon in the corner
# display(button_with_icon)

# %%
# import ipywidgets as widgets
# from IPython.display import display, HTML, Javascript

# # Load FontAwesome for icons
# fontawesome_css = """
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
# """

# # Create the button widget
# button = widgets.Button(description="My Buttonnn", layout=widgets.Layout(width='150px', height='50px'))

# # Display the button and icon in HTML
# button_with_icon = widgets.HTML(
#     value="""
#     <div style="position: relative; display: inline-block; width: 150px; height: 50px;">
#         <button style="width: 100%; height: 100%; background-color: lightblue; border: none; border-radius: 5px;">
#             My Button
#         </button>
#         <i class="fa fa-info-circle" style="position: absolute; top: 5px; right: 5px; font-size: 18px;"></i>
#     </div>
#     """
# )

# # Function to display the button and the CSS for icons
# def display_button():
#     display(HTML(fontawesome_css))
#     display(button_with_icon)

# display_button()

# %% [markdown]
# ```{hint}
# <b>State variable</b>: A formal measure that summarizes the state of a community or population at a particular time ({{ ref_intext_wearn_gloverkapfer_2017 }}), (e.g., species richness or population abundance).
# ```
