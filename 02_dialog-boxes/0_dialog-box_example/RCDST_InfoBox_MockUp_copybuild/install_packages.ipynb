# %%
pip install notebook
# Out:
# ...
#   Using cached notebook-7.2.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached notebook-7.2.0-py3-none-any.whl (5.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-book
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyterlab-myst
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupytext
# Out:
# ...
#   Using cached jupytext-1.16.2-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached jupytext-1.16.2-py3-none-any.whl (153 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
