# %% [markdown]
# # "How to" jupyter-web-app

# %% [markdown]
# ### Create and activate virtual environment.
#
# ##### Open anaconda prompt

# %%
conda create -n webapp
cd C:\Users\cassi\Documents\GitHub\1_GitHub_AB-RCSC\Jupyter-web-app-CASS
conda activate webapp

## Download and install visual-cpp-build-tools
## from https://visualstudio.microsoft.com/visual-cpp-build-tools/

# %%
## Install the dependencies
# !pip install -r r.txt

# %% [markdown]
# ![install-visual-studio.png](attachment:dd1352fb-6470-45e7-96fe-4d8531a6aa79.png)

# %% [markdown]
# * For additional dependencies, run below commands separately in one of your notebooks:

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: book console contrib dejavu events execute kernel
# kernelspec lab labextension labhub migrate nbclassic nbconvert
# nbextensions_configurator notebook qtconsole run script server troubleshoot
# ...

# %%
# !jupyter serverextension enable voila --sys-prefix
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: book console contrib dejavu events execute kernel
# kernelspec lab labextension labhub migrate nbclassic nbconvert
# nbextensions_configurator notebook qtconsole run script server troubleshoot
# ...

# %% [markdown]
# * For opening the notebook, change directory to the notebooks folder by "cd notebooks" and run "jupyter notebook". This will open the notebooks.

# %%
cd C:\Users\cassi\Documents\GitHub\AB-RCSC\Jupyter-web-app-CASS\notebooks
jupyter notebook

# %%
* For voila rendering, inside the same directory (notebooks), run "voila"

# %%
voila
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 voila
#
# NameError: name 'voila' is not defined
